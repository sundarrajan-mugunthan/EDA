# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rain_df = pd.read_csv('chennai_reservoir_rainfall.csv')
rain_df['Date'] = pd.to_datetime(rain_df['Date'])
rain_df.head()
# Out:
#         Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 0 2004-01-01     0.0         0.0       0.0              0.0
# 1 2004-02-01     0.0         0.0       0.0              0.0
# 2 2004-03-01     0.0         0.0       0.0              0.0
# 3 2004-04-01     0.0         0.0       0.0              0.0
# 4 2004-05-01     0.0         0.0       0.0              0.0

# %%
rain_df.tail()
# Out:
#            Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 5831 2019-12-19     0.0         0.0       0.0              0.0
# 5832 2019-12-20     0.0         0.0       0.0              0.0
# 5833 2019-12-21     0.0         0.0       0.0              0.0
# 5834 2019-12-22     0.0         0.0       0.0              0.0
# 5835 2019-12-23     0.0         0.0       0.0              0.0

# %%
rain_df.shape
# Out:
# (5836, 5)

# %%
rain_df.describe()
# Out:
#             POONDI   CHOLAVARAM     REDHILLS  CHEMBARAMBAKKAM
# count  5836.000000  5836.000000  5836.000000      5836.000000
# mean      3.464402     3.758773     3.828992         4.012688
# std      13.065897    14.267783    15.011809        16.251079
# min       0.000000     0.000000     0.000000         0.000000
# 25%       0.000000     0.000000     0.000000         0.000000
# 50%       0.000000     0.000000     0.000000         0.000000
# 75%       0.000000     0.000000     0.000000         0.000000
# max     300.000000   293.000000   320.000000       475.000000

# %%
rain_df.columns
# Out:
# Index(['Date', 'POONDI', 'CHOLAVARAM', 'REDHILLS', 'CHEMBARAMBAKKAM'], dtype='object')

# %%
rain_df.nunique(axis=0)
# Out:
# Date               5836
# POONDI              229
# CHOLAVARAM          111
# REDHILLS            177
# CHEMBARAMBAKKAM     126
# dtype: int64

# %%
rain_df.isnull().sum()
# Out:
# Date               0
# POONDI             0
# CHOLAVARAM         0
# REDHILLS           0
# CHEMBARAMBAKKAM    0
# dtype: int64

# %%
corelation = rain_df.corr()

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)

# %%
sns.pairplot(rain_df)

# %%
sns.displot(rain_df['POONDI'])

# %%
sns.displot(rain_df['CHOLAVARAM'])

# %%
sns.displot(rain_df['REDHILLS'])

# %%
sns.displot(rain_df['CHEMBARAMBAKKAM'])

# %%
sns.catplot(x='POONDI', kind='box', data=rain_df)

# %%
rainlvl_df = pd.read_csv('chennai_reservoir_levels.csv')
rainlvl_df.Date = pd.to_datetime(rainlvl_df.Date)
sns.displot(rainlvl_df)

# %%
sns.displot(rainlvl_df['POONDI'], bins=20)

# %%
sns.lineplot(x='Date', y='POONDI', data=rainlvl_df)

# %%
sns.pairplot(rainlvl_df)

# %%
sns.displot(rainlvl_df['POONDI'], kde=True)

# %%
sns.displot(x='Date', y='POONDI', data=rainlvl_df)

# %%
sns.displot(x='Date', y='CHOLAVARAM', data=rainlvl_df)

# %%
sns.displot(x='Date', y='REDHILLS', data=rainlvl_df)

# %%
sns.displot(x='Date', y='CHEMBARAMBAKKAM', data=rainlvl_df)

# %%
rainfall = rain_df.POONDI + rain_df.CHOLAVARAM + rain_df.REDHILLS + rain_df.CHEMBARAMBAKKAM
rainfall.plot(figsize=(20,10), linewidth=3, fontsize=15)
plt.xlabel('Date', fontsize=15)
plt.ylabel('rainfall', fontsize=15)
# Out:
# Text(0,0.5,'rainfall')

# %%
sns.relplot(x='Date', y='POONDI', data=rainlvl_df)

# %%
sns.lineplot(x='Date', y='POONDI', data=rainlvl_df)

# %%
corelation = rainlvl_df.corr()
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)
